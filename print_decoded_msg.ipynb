# %%
# test
import pandas as pd
file_path = "/root/autodl-tmp/emg2qwerty/logs/conformer_vs_0310/08-58-11/decoding_visualization/test_epoch_200.csv"

data = pd.read_csv(file_path)
pd.set_option('display.max_colwidth', None)
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          prediction  \
# ...

# %%
print(data['prediction'].str.len())
# Out:
# 0    944
# Name: prediction, dtype: int64

# %%
print(data['target'].str.len())
# Out:
# 0    4627
# Name: target, dtype: int64

# %%
print(data['prediction'])
# Out:
# 0    e irowupoglaz oak s rto⏎a oe⏎ etogiors⏎ aaeroet rsaetrrsa  atecaistrt  arsttpraruiest et aser ort⏎s rlasg atugn t s csugaer  aa⌫ ae r ton fattursetatteaaar⏎⌫crrarting ⌫⏎brosig cupvrag sct⌫ r⏎c coura⏎odever⌫c cere⏎aa tiiae⌫cagarsars⌫coacwirf⏎ecraads rrgtaidiatio ecrd⏎rc⌫⌫ s⏎aaesi apeor⏎seatiaa srergrerreserderreased s⏎freysed orsuresola ro⏎prtsycortm,⏎⌫rardee e⌫s⌫eocaois mseo cds i⏎liri edaorr eence ctinties rtaoratweit crsarg ⌫⌫tedctod ,⏎di ceosit ce r⏎asstreaid focsasaktdtradiesai aantees crat⏎edccsi as⏎icae deaaaao⏎t aredd st e sa⏎ccsecs orgut fabegie⌫c rs estato wdoe dee⏎des d⌫rrser⏎artrerei rasrrgdefweectidearot⏎eeesc⌫aeseae aewdas eeeeea⏎ee s ane efr⏎fsalihe ewwh⏎etga⏎lcawi attied fg lgh vetae foed ese f gat the  e⏎aoef r⏎⏎dadr ge⌫⌫femae⏎ ere⏎⏎e ee a⏎ terstiwwir⏎oo⌫alan n odliger aoe⏎gtossit,igaereaareorrere⏎codred⏎ re tar⏎ed ag⏎gi rw ⏎eseokar oeae⌫⌫⏎srrtesgrrrese⌫utoa ⏎aast⌫⌫sr ⌫f soe r⏎kig ⏎eeasldoartara g tg ⏎lfeaaaaee ⏎as
# Name: prediction, dtype: object

# %%
print(data['target'])
# Out:
# 0    the quick brown fox jumps over a lazy dog⏎thai adds strategic throw⏎literary mark indivb⌫idual frontpage⏎tiny correctly origin lotus⏎hull titanium bull annex⏎cleaning hdtv properties readers⏎may let;s⌫⌫'s adopt princess⏎chad realistic ultiate f⌫⌫⌫⌫⌫mate d⌫fifth⏎vampire bristol diagnosti =c⌫⌫⌫c journals⏎tile canberra damaged roster⏎percent percentage brilliant nike⏎set u⌫⌫up sheet washer fort⏎pastor douglas modeling chat⏎religions robert sara cotton⏎exposure cherry corners expensive⏎mediterranean tons prod⌫cedure occurred⏎environmental acts affar⌫irs allergy⏎thesarurus ⌫⌫⌫⌫s ⌫⌫⌫⌫urus populations firmware thoughts⏎nails filters routing sunset⏎matthew london italy garbage⏎o⌫contractig po⌫⌫⌫⌫ng posing chile several⏎knights special poverty ogg⌫⌫ffer⏎military bla⌫⌫alance principles dis⌫⌫⌫⌫⌫ distribution⏎disco hours counted lamps⏎penalties adverse does interference⏎livestock suited italia hydraulic⏎surrounding delivered annul⌫ally firer⌫wire⏎maria thinks haen⌫⌫ven later⏎nelson fear ste
# ...

# %%
# validation

# %%
import pandas as pd
file_path = "/root/autodl-tmp/emg2qwerty/logs/conformer_vs_0310/08-58-11/decoding_visualization/val_epoch_200.csv"

data = pd.read_csv(file_path)
pd.set_option('display.max_colwidth', None)
data
# Out:
#                    prediction                      target        cer
# 0                         NaN                         NaN   0.000000
# 1  the qiick brown fod jumps   the quick brown fox jumps    7.692308
# 2    ofer a lazy dog⏎spiritua   over a lazy dog⏎spiritual   8.000000
# 3          l vapoum cootees c         valium committees c  35.000000
# 4         ontesy⏎atoe jails c       ontest⏎cattle nails c  23.809524

# %%
for index, row in data.iterrows():
    print(f"sample {index}: prediction: {row['prediction']}; target: {row['target']}; cer: {row['cer']}")
# Out:
# sample 0: prediction: nan; target: nan; cer: 0.0
# sample 1: prediction: the qiick brown fod jumps ; target: the quick brown fox jumps ; cer: 7.6923076923076925
# sample 2: prediction: ofer a lazy dog⏎spiritua; target: over a lazy dog⏎spiritual; cer: 8.0
# sample 3: prediction: l vapoum cootees c; target:  valium committees c; cer: 35.0
# sample 4: prediction: ontesy⏎atoe jails c; target: ontest⏎cattle nails c; cer: 23.809523809523807
